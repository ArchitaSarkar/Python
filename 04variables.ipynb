# %%
name="Archita"
print(name)
# Out:
# Archita

# %%
name=Barsa
print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 name=Barsa
#       2 print(name)
#
# NameError: name 'Barsa' is not defined

# %%
name="Barsa"
print(name)
# Out:
# Barsa

# %%
# dynamic typing = you don't have to declare variable type
#in python dynamic typing is used

#static typing = you have to declare variable type
#in java static typing is used

# %%
name=5
print(name)
print(type(name))
# Out:
# 5
# <class 'int'>

# %%
name=True
print(name)
print(type(name))
# Out:
# True
# <class 'bool'>

# %%
# dynamic binding = variable type can change during execution
# in python dynamic binding is used

# static binding = variable type cannot change during execution
# in java static binding is used

# %%
a=1;b=2;c=3;
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=5;
print(a,b,c)
# Out:
# 5 5 5
