# %%
i=0
while i<5:
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# use of loop 
# in website we make one container and putting loop on dataset can generate multiple containers
# in games we use loop to keep the game running until some condition is met
# in apps we use loop to keep the app running until user closes it
