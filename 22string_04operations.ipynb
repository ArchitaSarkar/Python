# %%
# string operations
# arithmetic operators
# relational operators
# logical operators
# membership operators
# loops in strings

# %%
"hello" + " " + "world"  # concatenation
# Out:
# 'hello world'

# %%
print("hello " * 3)  # repetition
# Out:
# hello hello hello

# %%
"hello" == "hello"  # equality
# Out:
# True

# %%
"Goa" > "Delhi"  # lexicographical comparison
# Out:
# True

# %%
'a'>'A  # ASCII comparison' # small letters come after capital letters in ASCII table
# Out:
# True

# %%
"" and "world"  # logical AND
# Out:
# ''

# %%
"" or "world"  # logical OR
# Out:
# 'world'

# %%
"hello" or "world"  # logical OR
# Out:
# 'hello'

# %%
"hello" and "world"  # logical AND
# Out:
# 'world'

# %%
not ""
# Out:
# True

# %%
not "hello"  # logical NOT
# Out:
# False

# %%
for c in "hello":
    print(c)
# Out:
# h
# e
# l
# l
# o

# %%
c="hello"
'o' in c  # membership operator
# Out:
# True

# %%
'l' not in c
# Out:
# False

# %%
'hel' in c
# Out:
# True
