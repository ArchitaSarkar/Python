# %%
print("Hello World")
# Out:
# Hello World

# %%
print(842)
# Out:
# 842

# %%
print(7.65)
# Out:
# 7.65

# %%
print("india", "is", "my", "country", sep=" ",end="....")
# Out:
# india is my country....

# %%
print("Hello",end="!!!")
print("World")
# Out:
# Hello!!!World
