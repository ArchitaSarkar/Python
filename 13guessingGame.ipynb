# %%
import random
a=random.randint(1,100)
b=int(input("Guess the no.: "))
attempts=1 
while a!=b:
    if b>a :
        b=int(input("You choosed higher no .please enter smaller no."))
    elif a>b:
        b=int(input("You choosed lesser no .please enter higher no."))
    attempts+=1
if a==b :
    print("Bravo you gusessed it right at ",attempts,"no of attempts")
# Out:
# Bravo you gusessed it right at  3 no of attempts
