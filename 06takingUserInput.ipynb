# %%
input("What is your name? ")
# Out:
# 'Archita'

# %%
age=input("What is your age? ")

# %%
print(age)
# Out:
# 20

# %%
a=input("Enter a number: ")
print(a)
b=input("Enter another number: ")
print(b)
print(a+b)
# Out:
# 10
# 5
# 105

# %%
# string is a universal format can be used to represent any data type
# so input() function takes input as string by default
# to take input as integer or float we need to typecast it
