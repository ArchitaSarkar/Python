# %%
# common functions used in string , sets ,list, tuple, dictionary
# len
# max
# min
# sorted

# %%
c="hello world"
len(c)
# Out:
# 11

# %%
min(c)
# Out:
# ' '

# %%
max(c)
# Out:
# 'w'

# %%
sorted(c)
# Out:
# [' ', 'd', 'e', 'h', 'l', 'l', 'l', 'o', 'o', 'r', 'w']

# %%
sorted(c,reverse=True)
# Out:
# ['w', 'r', 'o', 'o', 'l', 'l', 'l', 'h', 'e', 'd', ' ']

# %%
# capitalize/Title/Upper/Lower/Swapcase
c="archita"
c.capitalize()
# Out:
# 'Archita'

# %%
"this is archita".title()
# Out:
# 'This Is Archita'

# %%
c.swapcase()
# Out:
# 'ARCHITA'

# %%
c.count("a")
# Out:
# 2

# %%
c.find('a')
# Out:
# 0

# %%
"Hi my name is {} and age is {}".format("Archita",20)
# Out:
# 'Hi my name is Archita and age is 20'

# %%
'Hi my name is Archita and age is 20'.split()
# Out:
# ['Hi', 'my', 'name', 'is', 'Archita', 'and', 'age', 'is', '20']

# %%
" ".join(['Hi', 'my', 'name', 'is', 'Archita', 'and', 'age', 'is', '20'])
# Out:
# 'Hi my name is Archita and age is 20'

# %%
name="        archita       "
print(name)
# Out:
#         archita

# %%
name.strip()
# Out:
# 'archita'
