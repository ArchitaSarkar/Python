# %%
#keywords in python variable naming conventions
# there are 33 keywords in python
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# identifiers = names given to variables, functions, classes, modules, etc.
# rules for naming identifiers
# 1. can contain letters (a-z, A-Z), digits (0-9), or underscores (_)
# 2. cannot start with a digit
# 3. cannot be a keyword
# 4. case-sensitive
# 5. no special characters allowed (like !, @, #, $, %, etc.)
# 6. cannot contain spaces
# 7. should be meaningful and descriptive
# examples of valid identifiers
my_variable = 10
