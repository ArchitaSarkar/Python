# %%
# operators
# Arithmetic operators: +, -, *, /, %, //, **
# Assignment operators: =, +=, -=, *=, /=, %=
# Comparison operators: ==, !=, >, <, >=, <=        
# Logical operators: and, or, not
# Identity operators: is, is not
# Membership operators: in, not in
# Bitwise operators: &, |, ^, ~, <<, >>

# %%
a=10
a++
++a
# Out:
#   Cell In[2], line 2
#     a++
#        ^
# SyntaxError: invalid syntax

# %%
#identify operator
x=5
y=5
print(x is y)  #True # from -5 to 255 python has assigined a memory address to each no as they are frequenly used .so if any identifier store them will all point to that address only 
a=800
b=800
print(a is b)
# Out:
# True
# False

# %%
x=True
y=False
print(x is y)  #False
# Out:
# False

# %%
x=[1,2,3]
y=[1,2,3]
print(x is y)  #False
# Out:
# False

# %%
# is operator compares memory address of two objects
# if both objects point to same memory location, it returns True else False

# %%
x="Kolkata" #membership operator
print('o' in x)  #True
print('z' in x)  #False
# Out:
# True
# False
