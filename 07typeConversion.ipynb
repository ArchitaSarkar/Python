# %%
# type conversion is of 2 type 
# implicit type conversion
# explicit type conversion
# implicit type conversion is done by python interpreter automatically
# explicit type conversion is done by user using built-in functions like int(), float(), str()

# %%
2+4.5
# Out:
# 6.5

# %%
2+9+8j
# Out:
# (11+8j)

# %%
int("123")
# Out:
# 123

# %%
str(123)
# Out:
# '123'

# %%
float("12.34")
# Out:
# 12.34

# %%
float(5)
# Out:
# 5.0

# %%
int(7.8)
# Out:
# 7

# %%
set("hello")
# Out:
# {'e', 'h', 'l', 'o'}

# %%
tuple("hello")
# Out:
# ('h', 'e', 'l', 'l', 'o')

# %%
list("hello")
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
dict("hello" \
"")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 dict("hello" \
#       2 "")
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
int("kolkata")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 int("kolkata")
#
# ValueError: invalid literal for int() with base 10: 'kolkata'

# %%
# type conversion is not a permanent change. It only changes the type for that particular operation.
#the original variable remains unchanged.`
# but type casting creates a new variable of the desired type.

# %%
a=int(input("Enter a number: "))
b=float(input("Enter a decimal number: "))
c=a+b
print("The sum is:",c)
# Out:
# The sum is: 7.5
